# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **read csv file**

# %%
df = pd.read_csv(r'cs2m.csv')

# %%
df
# Out:
#      BP  Chlstrl  Age  Prgnt  AnxtyLH  DrugR
# 0   100      150   20      0        0      0
# 1   120      160   16      0        0      0
# 2   110      150   18      0        0      0
# 3   100      175   25      0        0      0
# 4    95      250   36      0        0      0
# 5   110      200   56      0        1      0
# 6   120      180   59      0        1      0
# 7   150      175   45      0        1      0
# 8   160      185   40      0        1      0
# 9   125      195   20      1        0      0
# 10  135      190   18      1        0      0
# 11  165      200   25      1        0      0
# 12  145      175   30      1        0      0
# 13  120      180   28      1        0      0
# 14  100      180   21      1        0      0
# 15  100      160   19      1        0      1
# 16   95      250   18      1        0      1
# 17  120      200   30      1        0      1
# 18  125      240   29      1        0      1
# 19  130      172   30      1        0      1
# ...

# %% [markdown]
# **First 5 rows**

# %%
df.head()
# Out:
#     BP  Chlstrl  Age  Prgnt  AnxtyLH  DrugR
# 0  100      150   20      0        0      0
# 1  120      160   16      0        0      0
# 2  110      150   18      0        0      0
# 3  100      175   25      0        0      0
# 4   95      250   36      0        0      0

# %% [markdown]
# **last 5 cells**

# %%
df.tail()
# Out:
#      BP  Chlstrl  Age  Prgnt  AnxtyLH  DrugR
# 25  130      175   72      0        1      1
# 26  170      200   56      0        1      1
# 27  145      210   58      0        1      1
# 28  180      200   81      0        1      1
# 29  140      190   73      0        1      1

# %% [markdown]
# **shape of dataframe**

# %%
df.shape
# Out:
# (30, 6)

# %%
df.info()
#no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BP       30 non-null     int64
#  1   Chlstrl  30 non-null     int64
#  2   Age      30 non-null     int64
#  3   Prgnt    30 non-null     int64
#  4   AnxtyLH  30 non-null     int64
#  5   DrugR    30 non-null     int64
# dtypes: int64(6)
# memory usage: 1.5 KB

# %%
df.describe()
# Out:
#                BP     Chlstrl        Age      Prgnt    AnxtyLH      DrugR
# count   30.000000   30.000000  30.000000  30.000000  30.000000  30.000000
# mean   127.333333  185.066667  37.766667   0.500000   0.466667   0.500000
# std     22.846313   28.462841  18.795970   0.508548   0.507416   0.508548
# min     95.000000  130.000000  16.000000   0.000000   0.000000   0.000000
# 25%    111.250000  172.750000  22.000000   0.000000   0.000000   0.000000
# 50%    122.500000  182.500000  31.000000   0.500000   0.000000   0.500000
# 75%    143.750000  200.000000  53.250000   1.000000   1.000000   1.000000
# max    180.000000  250.000000  81.000000   1.000000   1.000000   1.000000

# %%
df1 = pd.read_csv('cs2m_missing.csv')

# %%
df1
# Out:
#        BP  Chlstrl   Age  Prgnt  AnxtyLH  DrugR
# 0   100.0    150.0  20.0      0        0      0
# 1   120.0    160.0  16.0      0        0      0
# 2   110.0    150.0  18.0      0        0      0
# 3   100.0    175.0  25.0      0        0      0
# 4    95.0    250.0  36.0      0        0      0
# 5   110.0    200.0  56.0      0        1      0
# 6   120.0    180.0  59.0      0        1      0
# 7   150.0    175.0  45.0      0        1      0
# 8   160.0    185.0  40.0      0        1      0
# 9   125.0      NaN  20.0      1        0      0
# 10  135.0    190.0  18.0      1        0      0
# 11  165.0    200.0  25.0      1        0      0
# 12  145.0    175.0  30.0      1        0      0
# 13    NaN    180.0  28.0      1        0      0
# 14  100.0    180.0  21.0      1        0      0
# 15  100.0    160.0  19.0      1        0      1
# 16   95.0    250.0  18.0      1        0      1
# 17  120.0    200.0  30.0      1        0      1
# 18  125.0    240.0   NaN      1        0      1
# ...

# %% [markdown]
# **missing value**

# %%
df1.isna().sum()
# Out:
# BP         2
# Chlstrl    1
# Age        1
# Prgnt      0
# AnxtyLH    0
# DrugR      0
# dtype: int64

# %% [markdown]
# **replace missing data with mean of column**

# %%
df1['BP'].mean()
# Out:
# 126.07142857142857

# %%
df1['BP'].fillna(df1['BP'].mean(),inplace = True)

# %%
df1.isna().sum()
# Out:
# BP         0
# Chlstrl    1
# Age        1
# Prgnt      0
# AnxtyLH    0
# DrugR      0
# dtype: int64

# %%
df1
# Out:
#             BP  Chlstrl   Age  Prgnt  AnxtyLH  DrugR
# 0   100.000000    150.0  20.0      0        0      0
# 1   120.000000    160.0  16.0      0        0      0
# 2   110.000000    150.0  18.0      0        0      0
# 3   100.000000    175.0  25.0      0        0      0
# 4    95.000000    250.0  36.0      0        0      0
# 5   110.000000    200.0  56.0      0        1      0
# 6   120.000000    180.0  59.0      0        1      0
# 7   150.000000    175.0  45.0      0        1      0
# 8   160.000000    185.0  40.0      0        1      0
# 9   125.000000      NaN  20.0      1        0      0
# 10  135.000000    190.0  18.0      1        0      0
# 11  165.000000    200.0  25.0      1        0      0
# 12  145.000000    175.0  30.0      1        0      0
# 13  126.071429    180.0  28.0      1        0      0
# 14  100.000000    180.0  21.0      1        0      0
# 15  100.000000    160.0  19.0      1        0      1
# 16   95.000000    250.0  18.0      1        0      1
# ...

# %%
df1['Chlstrl'].mean()
# Out:
# 184.72413793103448

# %%
df1['Chlstrl'].fillna(df1['Chlstrl'].mean(),inplace=True)

# %%
df1
# Out:
#             BP     Chlstrl   Age  Prgnt  AnxtyLH  DrugR
# 0   100.000000  150.000000  20.0      0        0      0
# 1   120.000000  160.000000  16.0      0        0      0
# 2   110.000000  150.000000  18.0      0        0      0
# 3   100.000000  175.000000  25.0      0        0      0
# 4    95.000000  250.000000  36.0      0        0      0
# 5   110.000000  200.000000  56.0      0        1      0
# 6   120.000000  180.000000  59.0      0        1      0
# 7   150.000000  175.000000  45.0      0        1      0
# 8   160.000000  185.000000  40.0      0        1      0
# 9   125.000000  184.724138  20.0      1        0      0
# 10  135.000000  190.000000  18.0      1        0      0
# 11  165.000000  200.000000  25.0      1        0      0
# 12  145.000000  175.000000  30.0      1        0      0
# 13  126.071429  180.000000  28.0      1        0      0
# 14  100.000000  180.000000  21.0      1        0      0
# 15  100.000000  160.000000  19.0      1        0      1
# ...

# %%
df1.isna().sum()
# Out:
# BP         0
# Chlstrl    0
# Age        1
# Prgnt      0
# AnxtyLH    0
# DrugR      0
# dtype: int64

# %%
df1['Age'].mode()[1]
# Out:
# 30.0

# %%
df1['Age'].mode()[0]
# Out:
# 18.0

# %%
df1['Age'].fillna(df1['Age'].mode()[1],inplace=True)

# %%
df1
# Out:
#             BP     Chlstrl   Age  Prgnt  AnxtyLH  DrugR
# 0   100.000000  150.000000  20.0      0        0      0
# 1   120.000000  160.000000  16.0      0        0      0
# 2   110.000000  150.000000  18.0      0        0      0
# 3   100.000000  175.000000  25.0      0        0      0
# 4    95.000000  250.000000  36.0      0        0      0
# 5   110.000000  200.000000  56.0      0        1      0
# 6   120.000000  180.000000  59.0      0        1      0
# 7   150.000000  175.000000  45.0      0        1      0
# 8   160.000000  185.000000  40.0      0        1      0
# 9   125.000000  184.724138  20.0      1        0      0
# 10  135.000000  190.000000  18.0      1        0      0
# 11  165.000000  200.000000  25.0      1        0      0
# 12  145.000000  175.000000  30.0      1        0      0
# 13  126.071429  180.000000  28.0      1        0      0
# 14  100.000000  180.000000  21.0      1        0      0
# 15  100.000000  160.000000  19.0      1        0      1
# ...

# %%
df1
# Out:
#             BP     Chlstrl   Age  Prgnt  AnxtyLH  DrugR
# 0   100.000000  150.000000  20.0      0        0      0
# 1   120.000000  160.000000  16.0      0        0      0
# 2   110.000000  150.000000  18.0      0        0      0
# 3   100.000000  175.000000  25.0      0        0      0
# 4    95.000000  250.000000  36.0      0        0      0
# 5   110.000000  200.000000  56.0      0        1      0
# 6   120.000000  180.000000  59.0      0        1      0
# 7   150.000000  175.000000  45.0      0        1      0
# 8   160.000000  185.000000  40.0      0        1      0
# 9   125.000000  184.724138  20.0      1        0      0
# 10  135.000000  190.000000  18.0      1        0      0
# 11  165.000000  200.000000  25.0      1        0      0
# 12  145.000000  175.000000  30.0      1        0      0
# 13  126.071429  180.000000  28.0      1        0      0
# 14  100.000000  180.000000  21.0      1        0      0
# 15  100.000000  160.000000  19.0      1        0      1
# ...

# %%
df1.isna().sum()
# Out:
# BP         0
# Chlstrl    0
# Age        0
# Prgnt      0
# AnxtyLH    0
# DrugR      0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BP       30 non-null     float64
#  1   Chlstrl  30 non-null     float64
#  2   Age      30 non-null     float64
#  3   Prgnt    30 non-null     int64
#  4   AnxtyLH  30 non-null     int64
#  5   DrugR    30 non-null     int64
# dtypes: float64(3), int64(3)
# memory usage: 1.5 KB

# %%
df1.describe()
